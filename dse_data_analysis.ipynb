# %%
import pandas as pd
import numpy as np
import matplotlib as mlb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock_data = pd.read_csv('Dhaka_Stock_Exchange_Data.csv')

# %%
stock_data.head()
# Out:
#          Date     Name   Open   High    Low  Close      Volume
# 0  02-01-2022  01.Bank  22.83  23.20  22.59  22.93  1842350.41
# 1  03-01-2022  01.Bank  23.03  23.29  22.74  22.90  1664989.63
# 2  04-01-2022  01.Bank  22.85  23.13  22.64  22.84  1354510.97
# 3  05-01-2022  01.Bank  22.91  23.20  22.70  22.98  1564334.81
# 4  06-01-2022  01.Bank  23.12  23.65  23.00  23.37  2586344.19

# %%
stock_data.shape
# Out:
# (49158, 7)

# %%
stock_data.dtypes
# Out:
# Date       object
# Name       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'], dayfirst=True)
stock_data.dtypes
# Out:
# Date      datetime64[ns]
# Name              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
stock_data['Date'].max()
# Out:
# Timestamp('2022-06-30 00:00:00')

# %%
stock_data['Open'].describe()
# Out:
# count    49158.000000
# mean       157.869018
# std        520.191624
# min          3.900000
# 25%         19.000000
# 50%         40.300000
# 75%         89.400000
# max       6000.000000
# Name: Open, dtype: float64

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]

plt.figure(figsize=(12,6))

for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    plt.plot(company_data['Date'],company_data['Close'],label=company)
    
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Stock Price Trend for Specific Comapnies')
plt.legend()
plt.grid()

plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(stock_data['Close'])
plt.title('Boxplot of Close Prices')
plt.xlabel('Close Price')
plt.show()

# %%
specific_companies=['UNILEVERCL']   #[,'BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]

plt.figure(figsize=(12,6))

for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    #plt.plot(company_data['Date'],company_data['Close'],label=company)
    sns.boxplot(company_data['Close'])
    
plt.title('Boxplot of Closing Prices')
plt.xlabel('Close Price')
plt.ylabel('Date')
plt.show()
plt.legend()
plt.grid()

plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 10
#       8     company_data=specific_data[specific_data['Name']==company]
#       9     #plt.plot(company_data['Date'],company_data['Close'],label=company)
# ---> 10     sns.boxplot(company_data['Close'])
#      12 plt.title('Boxplot of Closing Prices')
#      13 plt.xlabel('Close Price')
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:486, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     484 if hasattr(data, "shape"):
#     485     if len(data.shape) == 1:
# --> 486         if np.isscalar(data[0]):
#     487             plot_data = [data]
#     488         else:
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
company_data
# Out:
#             Date        Name    Open    High     Low   Close  Volume
# 8426  2022-01-02  UNILEVERCL  3000.0  3079.0  2985.0  3016.0  1753.0
# 8427  2022-01-03  UNILEVERCL  3080.0  3080.0  2975.0  2977.7  2172.0
# 8428  2022-01-04  UNILEVERCL  3015.0  3015.0  2955.0  2994.3  1454.0
# 8429  2022-01-05  UNILEVERCL  2995.0  3033.0  2995.0  2999.6  3352.0
# 8430  2022-01-06  UNILEVERCL  3002.0  3015.0  2950.0  2963.6  3650.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 48713 2022-06-26  UNILEVERCL  2810.1  2846.0  2810.1  2836.5   119.0
# 48714 2022-06-27  UNILEVERCL  2821.0  2845.0  2821.0  2832.2   217.0
# 48715 2022-06-28  UNILEVERCL  2840.0  2848.0  2840.0  2847.1   460.0
# 48716 2022-06-29  UNILEVERCL  2826.0  2855.0  2826.0  2839.0    68.0
# 48717 2022-06-30  UNILEVERCL  2850.0  2880.0  2828.0  2855.7   239.0
#
# [121 rows x 7 columns]

# %%
specific_data
# Out:
#             Date        Name    Open    High     Low   Close    Volume
# 1501  2022-01-02       BATBC   637.0   647.2   636.4   646.1  131289.0
# 1502  2022-01-03       BATBC   647.3   660.0   646.1   652.9  283257.0
# 1503  2022-01-04       BATBC   650.0   652.0   646.8   647.4   95460.0
# 1504  2022-01-05       BATBC   649.0   653.1   647.0   651.2  156364.0
# 1505  2022-01-06       BATBC   651.2   658.0   649.1   655.5  214376.0
# ...          ...         ...     ...     ...     ...     ...       ...
# 48713 2022-06-26  UNILEVERCL  2810.1  2846.0  2810.1  2836.5     119.0
# 48714 2022-06-27  UNILEVERCL  2821.0  2845.0  2821.0  2832.2     217.0
# 48715 2022-06-28  UNILEVERCL  2840.0  2848.0  2840.0  2847.1     460.0
# 48716 2022-06-29  UNILEVERCL  2826.0  2855.0  2826.0  2839.0      68.0
# 48717 2022-06-30  UNILEVERCL  2850.0  2880.0  2828.0  2855.7     239.0
#
# [607 rows x 7 columns]

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    print(f"Name of company: {company}")
    print(company_data['Open'].describe())
    print(company_data['High'].describe())
    print(company_data['Low'].describe())
    print(company_data['Close'].describe())
    print(company_data['Volume'].describe())
# Out:
# Name of company: UNILEVERCL
# count     121.000000
# mean     2944.022314
# std       162.931693
# min      2755.000000
# 25%      2822.000000
# 50%      2866.300000
# 75%      3044.000000
# max      3300.000000
# Name: Open, dtype: float64
# Name of company: BEXIMCO
# count    122.000000
# mean     146.202459
# std        8.413944
# min      127.100000
# 25%      138.300000
# 50%      148.550000
# 75%      152.075000
# max      162.300000
# Name: Open, dtype: float64
# Name of company: RECKITTBEN
# count     121.000000
# mean     5356.684298
# std       437.598174
# min      4680.000000
# 25%      4900.000000
# 50%      5385.100000
# 75%      5800.000000
# max      6000.000000
# Name: Open, dtype: float64
# Name of company: BATBC
# count    121.000000
# mean     596.112397
# std       40.223005
# min      539.500000
# 25%      568.200000
# 50%      584.600000
# 75%      635.000000
# max      699.300000
# Name: Open, dtype: float64
# Name of company: SAIHAMCOT
# count    122.000000
# mean      16.467213
# std        0.720702
# min       14.700000
# 25%       16.100000
# 50%       16.500000
# 75%       16.800000
# max       18.900000
# Name: Open, dtype: float64

# %%
company_data
# Out:
#             Date       Name  Open  High   Low  Close     Volume
# 7249  2022-01-02  SAIHAMCOT  16.0  16.1  15.8   15.9   173534.0
# 7250  2022-01-03  SAIHAMCOT  16.0  16.4  16.0   16.1   203237.0
# 7251  2022-01-04  SAIHAMCOT  16.1  16.3  16.0   16.1   158972.0
# 7252  2022-01-05  SAIHAMCOT  16.0  16.8  16.0   16.7   461593.0
# 7253  2022-01-06  SAIHAMCOT  16.7  16.8  16.5   16.6   269754.0
# ...          ...        ...   ...   ...   ...    ...        ...
# 47538 2022-06-26  SAIHAMCOT  16.6  16.7  16.2   16.3   807652.0
# 47539 2022-06-27  SAIHAMCOT  16.4  16.6  16.3   16.4   715518.0
# 47540 2022-06-28  SAIHAMCOT  16.6  17.0  16.4   16.9  2118497.0
# 47541 2022-06-29  SAIHAMCOT  16.9  17.3  16.7   17.1  2093590.0
# 47542 2022-06-30  SAIHAMCOT  16.8  17.5  16.8   17.2  2416422.0
#
# [122 rows x 7 columns]

# %%
company_data['Open'].describe()
# Out:
# count    122.000000
# mean      16.467213
# std        0.720702
# min       14.700000
# 25%       16.100000
# 50%       16.500000
# 75%       16.800000
# max       18.900000
# Name: Open, dtype: float64

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    company_data['Open'].describe()

# %%
company_data.dtypes
# Out:
# Date      datetime64[ns]
# Name              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]

#Identifying outliers in closing prices

for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    Q1=company_data['Close'].quantile(0.25)
    Q3=company_data['Close'].quantile(0.75)
    IQR=Q3-Q1
    lower_limit=Q1-1.5*IQR
    upper_limit=Q3+1.5*IQR
    outliers=company_data[(company_data['Close']<lower_limit)|(company_data['Close']>upper_limit)]
    print(outliers)
# Out:
#            Date        Name    Open    High     Low   Close   Volume
# 8445 2022-01-27  UNILEVERCL  3247.9  3302.7  3125.0  3298.9  10054.0
# Empty DataFrame
# Columns: [Date, Name, Open, High, Low, Close, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, Name, Open, High, Low, Close, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, Name, Open, High, Low, Close, Volume]
# Index: []
#            Date       Name  Open  High   Low  Close     Volume
# 7266 2022-01-25  SAIHAMCOT  17.3  18.1  17.1   18.0  1334852.0
# 7267 2022-01-26  SAIHAMCOT  18.1  18.3  17.5   17.9   956838.0
# 7268 2022-01-27  SAIHAMCOT  18.0  18.4  17.7   18.0   967311.0

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    plt.plot(company_data['Date'],company_data['Close'].pct_change(),label=company)
    
plt.xlabel('Date')
plt.ylabel('% Change in closing price')
plt.legend()

plt.grid()

plt.xticks(rotation=45)
plt.show()

# %%
specific_companies=['UNILEVERCL']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    plt.plot(company_data['Date'],company_data['Close'],label="Original")
    plt.plot(company_data['Date'],company_data['Close'].rolling(15).mean(),label="15-day MA")
    plt.plot(company_data['Date'],company_data['Close'].rolling(30).mean(),label="30-day MA")
    
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.grid()

plt.xticks(rotation=45)
plt.show()

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    print(f"Average closing price of {company} is: {company_data['Close'].mean()}")
# Out:
# Average closing price of UNILEVERCL is: 2935.0537190082646
# Average closing price of BEXIMCO is: 145.46475409836066
# Average closing price of RECKITTBEN is: 5342.024793388429
# Average closing price of BATBC is: 594.1231404958677
# Average closing price of SAIHAMCOT is: 16.345081967213115

# %%
stock_data.groupby('Name')['Close'].mean().sort_values(ascending=False).head(5)
# Out:
# Name
# APSCLBOND     5413.238636
# RECKITTBEN    5342.024793
# PREBPBOND     4918.357143
# IBBL2PBOND    4851.330357
# PBLPBOND      4836.195652
# Name: Close, dtype: float64

# %%
stock_data.groupby('Name')['Close'].mean().sort_values().head(5)
# Out:
# Name
# FAMILYTEX     4.698361
# ICBIBANK      4.725620
# FBFIF         5.289344
# POPULAR1MF    5.368033
# PHPMF1        5.417213
# Name: Close, dtype: float64

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    plt.plot(company_data['Date'],company_data['Close'].rolling(15).std(),label=company)
    
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('15-Day rolling std deviation of close prices')
plt.legend()

plt.grid()

plt.xticks(rotation=45)
plt.show()

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
    print(company_data)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
#             Date        Name    Open    High     Low   Close  Volume  \
# 8426  2022-01-02  UNILEVERCL  3000.0  3079.0  2985.0  3016.0  1753.0
# 8427  2022-01-03  UNILEVERCL  3080.0  3080.0  2975.0  2977.7  2172.0
# 8428  2022-01-04  UNILEVERCL  3015.0  3015.0  2955.0  2994.3  1454.0
# 8429  2022-01-05  UNILEVERCL  2995.0  3033.0  2995.0  2999.6  3352.0
# 8430  2022-01-06  UNILEVERCL  3002.0  3015.0  2950.0  2963.6  3650.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 48713 2022-06-26  UNILEVERCL  2810.1  2846.0  2810.1  2836.5   119.0
# 48714 2022-06-27  UNILEVERCL  2821.0  2845.0  2821.0  2832.2   217.0
# 48715 2022-06-28  UNILEVERCL  2840.0  2848.0  2840.0  2847.1   460.0
# 48716 2022-06-29  UNILEVERCL  2826.0  2855.0  2826.0  2839.0    68.0
# 48717 2022-06-30  UNILEVERCL  2850.0  2880.0  2828.0  2855.7   239.0
#
#        Price Change
# 8426           16.0
# 8427         -102.3
# 8428          -20.7
# 8429            4.6
# 8430          -38.4
# ...             ...
# 48713          26.4
# 48714          11.2
# 48715           7.1
# 48716          13.0
# 48717           5.7
#
# [121 rows x 8 columns]
#             Date     Name   Open   High    Low  Close      Volume  \
# 1828  2022-01-02  BEXIMCO  150.3  154.5  149.5  154.1   6482374.0
# 1829  2022-01-03  BEXIMCO  155.4  159.9  154.6  156.9  11519937.0
# 1830  2022-01-04  BEXIMCO  157.4  157.4  151.6  152.6   6918142.0
# 1831  2022-01-05  BEXIMCO  153.5  154.0  149.5  150.0   6632703.0
# 1832  2022-01-06  BEXIMCO  151.1  152.0  149.0  149.9   7455503.0
# ...          ...      ...    ...    ...    ...    ...         ...
# 42104 2022-06-26  BEXIMCO  135.8  135.9  132.2  132.2   1460443.0
# 42105 2022-06-27  BEXIMCO  131.5  133.1  131.0  132.3   3483385.0
# 42106 2022-06-28  BEXIMCO  131.8  133.2  131.3  132.4   2200022.0
# 42107 2022-06-29  BEXIMCO  131.5  133.5  130.7  131.2   1763487.0
# 42108 2022-06-30  BEXIMCO  131.9  132.0  129.4  129.8   2808804.0
#
#        Price Change
# 1828            3.8
# 1829            1.5
# 1830           -4.8
# 1831           -3.5
# 1832           -1.2
# ...             ...
# 42104          -3.6
# 42105           0.8
# 42106           0.6
# 42107          -0.3
# 42108          -2.1
#
# [122 rows x 8 columns]
#             Date        Name    Open    High     Low   Close  Volume  \
# 6875  2022-01-02  RECKITTBEN  5760.1  5889.0  5748.1  5816.1  1592.0
# 6876  2022-01-03  RECKITTBEN  5795.0  5823.9  5630.0  5655.2  1492.0
# 6877  2022-01-04  RECKITTBEN  5670.0  5670.0  5560.0  5609.9  1394.0
# 6878  2022-01-05  RECKITTBEN  5600.0  5738.8  5600.0  5725.6   323.0
# 6879  2022-01-06  RECKITTBEN  5640.3  5680.0  5616.0  5640.1   767.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 47166 2022-06-26  RECKITTBEN  4840.0  4855.0  4770.0  4819.7  1007.0
# 47167 2022-06-27  RECKITTBEN  4819.7  4869.0  4806.0  4837.6   836.0
# 47168 2022-06-28  RECKITTBEN  4830.9  4880.0  4805.1  4829.0   400.0
# 47169 2022-06-29  RECKITTBEN  4900.0  4900.0  4811.5  4830.1   433.0
# 47170 2022-06-30  RECKITTBEN  4830.1  4890.1  4781.0  4868.5   485.0
#
#        Price Change
# 6875           56.0
# 6876         -139.8
# 6877          -60.1
# 6878          125.6
# 6879           -0.2
# ...             ...
# 47166         -20.3
# 47167          17.9
# 47168          -1.9
# 47169         -69.9
# 47170          38.4
#
# [121 rows x 8 columns]
#             Date   Name   Open   High    Low  Close    Volume  Price Change
# 1501  2022-01-02  BATBC  637.0  647.2  636.4  646.1  131289.0           9.1
# 1502  2022-01-03  BATBC  647.3  660.0  646.1  652.9  283257.0           5.6
# 1503  2022-01-04  BATBC  650.0  652.0  646.8  647.4   95460.0          -2.6
# 1504  2022-01-05  BATBC  649.0  653.1  647.0  651.2  156364.0           2.2
# 1505  2022-01-06  BATBC  651.2  658.0  649.1  655.5  214376.0           4.3
# ...          ...    ...    ...    ...    ...    ...       ...           ...
# 41754 2022-06-26  BATBC  545.0  545.0  542.5  542.7   52191.0          -2.3
# 41755 2022-06-27  BATBC  542.3  545.0  541.0  541.4  104386.0          -0.9
# 41756 2022-06-28  BATBC  543.7  544.0  541.0  541.9  161737.0          -1.8
# 41757 2022-06-29  BATBC  542.1  544.0  541.5  542.6  141003.0           0.5
# 41758 2022-06-30  BATBC  543.6  547.9  542.5  543.5  121785.0          -0.1
#
# [121 rows x 8 columns]
#             Date       Name  Open  High   Low  Close     Volume  Price Change
# 7249  2022-01-02  SAIHAMCOT  16.0  16.1  15.8   15.9   173534.0          -0.1
# 7250  2022-01-03  SAIHAMCOT  16.0  16.4  16.0   16.1   203237.0           0.1
# 7251  2022-01-04  SAIHAMCOT  16.1  16.3  16.0   16.1   158972.0           0.0
# 7252  2022-01-05  SAIHAMCOT  16.0  16.8  16.0   16.7   461593.0           0.7
# 7253  2022-01-06  SAIHAMCOT  16.7  16.8  16.5   16.6   269754.0          -0.1
# ...          ...        ...   ...   ...   ...    ...        ...           ...
# 47538 2022-06-26  SAIHAMCOT  16.6  16.7  16.2   16.3   807652.0          -0.3
# 47539 2022-06-27  SAIHAMCOT  16.4  16.6  16.3   16.4   715518.0           0.0
# 47540 2022-06-28  SAIHAMCOT  16.6  17.0  16.4   16.9  2118497.0           0.3
# 47541 2022-06-29  SAIHAMCOT  16.9  17.3  16.7   17.1  2093590.0           0.2
# 47542 2022-06-30  SAIHAMCOT  16.8  17.5  16.8   17.2  2416422.0           0.4
#
# [122 rows x 8 columns]
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
    plt.plot(company_data['Date'],company_data['Price Change'],label=company)
    
plt.xlabel('Date')
plt.ylabel('Price Change')
plt.title('Distribution of Price Change')
plt.legend()

plt.grid()

plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\862163033.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\862163033.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\862163033.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\862163033.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\862163033.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)

# %%
specific_data['Price Change']=specific_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\210312176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_data['Price Change']=specific_data.apply(lambda row: row['Close'] - row['Open'], axis=1)

# %%
specific_data
# Out:
#             Date        Name    Open    High     Low   Close  Volume  \
# 8426  2022-01-02  UNILEVERCL  3000.0  3079.0  2985.0  3016.0  1753.0
# 8427  2022-01-03  UNILEVERCL  3080.0  3080.0  2975.0  2977.7  2172.0
# 8428  2022-01-04  UNILEVERCL  3015.0  3015.0  2955.0  2994.3  1454.0
# 8429  2022-01-05  UNILEVERCL  2995.0  3033.0  2995.0  2999.6  3352.0
# 8430  2022-01-06  UNILEVERCL  3002.0  3015.0  2950.0  2963.6  3650.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 48713 2022-06-26  UNILEVERCL  2810.1  2846.0  2810.1  2836.5   119.0
# 48714 2022-06-27  UNILEVERCL  2821.0  2845.0  2821.0  2832.2   217.0
# 48715 2022-06-28  UNILEVERCL  2840.0  2848.0  2840.0  2847.1   460.0
# 48716 2022-06-29  UNILEVERCL  2826.0  2855.0  2826.0  2839.0    68.0
# 48717 2022-06-30  UNILEVERCL  2850.0  2880.0  2828.0  2855.7   239.0
#
#        Price Change
# 8426           16.0
# 8427         -102.3
# 8428          -20.7
# 8429            4.6
# 8430          -38.4
# ...             ...
# 48713          26.4
# 48714          11.2
# 48715           7.1
# 48716          13.0
# 48717           5.7
#
# [121 rows x 8 columns]

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
    print(company_data.sort_values(by='Price Change',ascending=False).head(5))
# Out:
#             Date        Name    Open    High     Low   Close   Volume  \
# 8442  2022-01-24  UNILEVERCL  3134.0  3239.0  3100.0  3221.2   8230.0
# 24912 2022-03-15  UNILEVERCL  2820.2  2880.0  2820.2  2876.0   1152.0
# 8439  2022-01-19  UNILEVERCL  3016.8  3084.0  3016.8  3068.5    993.0
# 8445  2022-01-27  UNILEVERCL  3247.9  3302.7  3125.0  3298.9  10054.0
# 32629 2022-04-13  UNILEVERCL  2780.0  2829.7  2770.0  2827.1    567.0
#
#        Price Change
# 8442           87.2
# 24912          55.8
# 8439           51.7
# 8445           51.0
# 32629          47.1
#             Date     Name   Open   High    Low  Close      Volume  \
# 1842  2022-01-20  BEXIMCO  153.2  161.9  153.2  160.4  15724293.0
# 1841  2022-01-19  BEXIMCO  145.0  152.7  144.0  151.7  11856036.0
# 10467 2022-02-16  BEXIMCO  145.4  153.9  145.3  150.8   9215324.0
# 18371 2022-03-22  BEXIMCO  155.2  161.0  155.0  160.4   8563022.0
# 34528 2022-05-25  BEXIMCO  127.1  131.9  125.1  131.4   3586304.0
#
#        Price Change
# 1842            7.2
# 1841            6.7
# 10467           5.4
# 18371           5.2
# 34528           4.3
#             Date        Name    Open    High     Low   Close  Volume  \
# 6878  2022-01-05  RECKITTBEN  5600.0  5738.8  5600.0  5725.6   323.0
# 38613 2022-05-05  RECKITTBEN  4871.3  5079.0  4871.3  4994.7  1126.0
# 38618 2022-05-12  RECKITTBEN  4881.0  5015.0  4881.0  4999.5   251.0
# 31299 2022-04-10  RECKITTBEN  5142.0  5340.0  5142.0  5245.7   205.0
# 23375 2022-03-22  RECKITTBEN  5365.0  5500.0  5365.0  5449.0  1201.0
#
#        Price Change
# 6878          125.6
# 38613         123.4
# 38618         118.5
# 31299         103.7
# 23375          84.0
#             Date   Name   Open   High    Low  Close    Volume  Price Change
# 1516  2022-01-23  BATBC  648.0  669.5  648.0  663.3  489015.0          15.3
# 41739 2022-06-05  BATBC  555.7  571.8  554.4  570.3   89533.0          14.6
# 10161 2022-02-13  BATBC  625.0  640.0  624.0  638.5  304876.0          13.5
# 10168 2022-02-23  BATBC  610.5  626.9  610.1  623.6  119694.0          13.1
# 1501  2022-01-02  BATBC  637.0  647.2  636.4  646.1  131289.0           9.1
#             Date       Name  Open  High   Low  Close     Volume  Price Change
# 38919 2022-05-08  SAIHAMCOT  16.6  17.6  16.4   17.5  2662946.0           0.9
# 7266  2022-01-25  SAIHAMCOT  17.3  18.1  17.1   18.0  1334852.0           0.7
# 7252  2022-01-05  SAIHAMCOT  16.0  16.8  16.0   16.7   461593.0           0.7
# 7263  2022-01-20  SAIHAMCOT  16.7  17.8  16.7   17.3  1997301.0           0.6
# 47526 2022-06-08  SAIHAMCOT  16.0  16.7  16.0   16.5   306457.0           0.5
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\1083571629.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\1083571629.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\1083571629.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\1083571629.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\1083571629.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
    print(company_data['Volume'].corr(company_data['Price Change'].rolling(7).std()))
    plt.scatter(company_data['Volume'],company_data['Price Change'].rolling(7).std(),label=company)

plt.legend()

plt.grid()

plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\324275592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\324275592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\324275592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\324275592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\324275592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# 0.47618119531595454
# 0.5236360804009472
# 0.16306219579853048
# 0.5002902873344605
# 0.274753079932992

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    print(company_data[['Open','High','Low','Close']].corr())
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.984735  0.978935  0.974837
# High   0.984735  1.000000  0.976807  0.981716
# Low    0.978935  0.976807  1.000000  0.988383
# Close  0.974837  0.981716  0.988383  1.000000
#            Open      High       Low     Close
# Open   1.000000  0.977330  0.977721  0.955140
# High   0.977330  1.000000  0.974154  0.981667
# Low    0.977721  0.974154  1.000000  0.983281
# Close  0.955140  0.981667  0.983281  1.000000
#            Open      High       Low     Close
# Open   1.000000  0.994625  0.994077  0.991214
# High   0.994625  1.000000  0.993983  0.995396
# Low    0.994077  0.993983  1.000000  0.997420
# Close  0.991214  0.995396  0.997420  1.000000
#            Open      High       Low     Close
# Open   1.000000  0.993734  0.989309  0.987418
# High   0.993734  1.000000  0.989250  0.993008
# Low    0.989309  0.989250  1.000000  0.995488
# Close  0.987418  0.993008  0.995488  1.000000
#            Open      High       Low     Close
# Open   1.000000  0.952600  0.931287  0.886257
# High   0.952600  1.000000  0.937535  0.952551
# Low    0.931287  0.937535  1.000000  0.958458
# Close  0.886257  0.952551  0.958458  1.000000

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    sns.heatmap(company_data[['Open','High','Low','Close']].corr(),annot=True)

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
    print(company_data)
# Out:
#             Date        Name    Open    High     Low   Close  Volume  \
# 8426  2022-01-02  UNILEVERCL  3000.0  3079.0  2985.0  3016.0  1753.0
# 8427  2022-01-03  UNILEVERCL  3080.0  3080.0  2975.0  2977.7  2172.0
# 8428  2022-01-04  UNILEVERCL  3015.0  3015.0  2955.0  2994.3  1454.0
# 8429  2022-01-05  UNILEVERCL  2995.0  3033.0  2995.0  2999.6  3352.0
# 8430  2022-01-06  UNILEVERCL  3002.0  3015.0  2950.0  2963.6  3650.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 48713 2022-06-26  UNILEVERCL  2810.1  2846.0  2810.1  2836.5   119.0
# 48714 2022-06-27  UNILEVERCL  2821.0  2845.0  2821.0  2832.2   217.0
# 48715 2022-06-28  UNILEVERCL  2840.0  2848.0  2840.0  2847.1   460.0
# 48716 2022-06-29  UNILEVERCL  2826.0  2855.0  2826.0  2839.0    68.0
# 48717 2022-06-30  UNILEVERCL  2850.0  2880.0  2828.0  2855.7   239.0
#
#        Price Change
# 8426           16.0
# 8427         -102.3
# 8428          -20.7
# 8429            4.6
# 8430          -38.4
# ...             ...
# 48713          26.4
# 48714          11.2
# 48715           7.1
# 48716          13.0
# 48717           5.7
#
# [121 rows x 8 columns]
#             Date     Name   Open   High    Low  Close      Volume  \
# 1828  2022-01-02  BEXIMCO  150.3  154.5  149.5  154.1   6482374.0
# 1829  2022-01-03  BEXIMCO  155.4  159.9  154.6  156.9  11519937.0
# 1830  2022-01-04  BEXIMCO  157.4  157.4  151.6  152.6   6918142.0
# 1831  2022-01-05  BEXIMCO  153.5  154.0  149.5  150.0   6632703.0
# 1832  2022-01-06  BEXIMCO  151.1  152.0  149.0  149.9   7455503.0
# ...          ...      ...    ...    ...    ...    ...         ...
# 42104 2022-06-26  BEXIMCO  135.8  135.9  132.2  132.2   1460443.0
# 42105 2022-06-27  BEXIMCO  131.5  133.1  131.0  132.3   3483385.0
# 42106 2022-06-28  BEXIMCO  131.8  133.2  131.3  132.4   2200022.0
# 42107 2022-06-29  BEXIMCO  131.5  133.5  130.7  131.2   1763487.0
# 42108 2022-06-30  BEXIMCO  131.9  132.0  129.4  129.8   2808804.0
#
#        Price Change
# 1828            3.8
# 1829            1.5
# 1830           -4.8
# 1831           -3.5
# 1832           -1.2
# ...             ...
# 42104          -3.6
# 42105           0.8
# 42106           0.6
# 42107          -0.3
# 42108          -2.1
#
# [122 rows x 8 columns]
#             Date        Name    Open    High     Low   Close  Volume  \
# 6875  2022-01-02  RECKITTBEN  5760.1  5889.0  5748.1  5816.1  1592.0
# 6876  2022-01-03  RECKITTBEN  5795.0  5823.9  5630.0  5655.2  1492.0
# 6877  2022-01-04  RECKITTBEN  5670.0  5670.0  5560.0  5609.9  1394.0
# 6878  2022-01-05  RECKITTBEN  5600.0  5738.8  5600.0  5725.6   323.0
# 6879  2022-01-06  RECKITTBEN  5640.3  5680.0  5616.0  5640.1   767.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 47166 2022-06-26  RECKITTBEN  4840.0  4855.0  4770.0  4819.7  1007.0
# 47167 2022-06-27  RECKITTBEN  4819.7  4869.0  4806.0  4837.6   836.0
# 47168 2022-06-28  RECKITTBEN  4830.9  4880.0  4805.1  4829.0   400.0
# 47169 2022-06-29  RECKITTBEN  4900.0  4900.0  4811.5  4830.1   433.0
# 47170 2022-06-30  RECKITTBEN  4830.1  4890.1  4781.0  4868.5   485.0
#
#        Price Change
# 6875           56.0
# 6876         -139.8
# 6877          -60.1
# 6878          125.6
# 6879           -0.2
# ...             ...
# 47166         -20.3
# 47167          17.9
# 47168          -1.9
# 47169         -69.9
# 47170          38.4
#
# [121 rows x 8 columns]
#             Date   Name   Open   High    Low  Close    Volume  Price Change
# 1501  2022-01-02  BATBC  637.0  647.2  636.4  646.1  131289.0           9.1
# 1502  2022-01-03  BATBC  647.3  660.0  646.1  652.9  283257.0           5.6
# 1503  2022-01-04  BATBC  650.0  652.0  646.8  647.4   95460.0          -2.6
# 1504  2022-01-05  BATBC  649.0  653.1  647.0  651.2  156364.0           2.2
# 1505  2022-01-06  BATBC  651.2  658.0  649.1  655.5  214376.0           4.3
# ...          ...    ...    ...    ...    ...    ...       ...           ...
# 41754 2022-06-26  BATBC  545.0  545.0  542.5  542.7   52191.0          -2.3
# 41755 2022-06-27  BATBC  542.3  545.0  541.0  541.4  104386.0          -0.9
# 41756 2022-06-28  BATBC  543.7  544.0  541.0  541.9  161737.0          -1.8
# 41757 2022-06-29  BATBC  542.1  544.0  541.5  542.6  141003.0           0.5
# 41758 2022-06-30  BATBC  543.6  547.9  542.5  543.5  121785.0          -0.1
#
# [121 rows x 8 columns]
#             Date       Name  Open  High   Low  Close     Volume  Price Change
# 7249  2022-01-02  SAIHAMCOT  16.0  16.1  15.8   15.9   173534.0          -0.1
# 7250  2022-01-03  SAIHAMCOT  16.0  16.4  16.0   16.1   203237.0           0.1
# 7251  2022-01-04  SAIHAMCOT  16.1  16.3  16.0   16.1   158972.0           0.0
# 7252  2022-01-05  SAIHAMCOT  16.0  16.8  16.0   16.7   461593.0           0.7
# 7253  2022-01-06  SAIHAMCOT  16.7  16.8  16.5   16.6   269754.0          -0.1
# ...          ...        ...   ...   ...   ...    ...        ...           ...
# 47538 2022-06-26  SAIHAMCOT  16.6  16.7  16.2   16.3   807652.0          -0.3
# 47539 2022-06-27  SAIHAMCOT  16.4  16.6  16.3   16.4   715518.0           0.0
# 47540 2022-06-28  SAIHAMCOT  16.6  17.0  16.4   16.9  2118497.0           0.3
# 47541 2022-06-29  SAIHAMCOT  16.9  17.3  16.7   17.1  2093590.0           0.2
# 47542 2022-06-30  SAIHAMCOT  16.8  17.5  16.8   17.2  2416422.0           0.4
#
# [122 rows x 8 columns]
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_40572\2956354959.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_data['Price Change']=company_data.apply(lambda row: row['Close'] - row['Open'], axis=1)

# %%
specific_companies=['UNILEVERCL']#,'BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]

for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    sns.boxplot(company_data['Close'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 7
#       5 for company in specific_companies:
#       6     company_data=specific_data[specific_data['Name']==company]
# ----> 7     sns.boxplot(company_data['Close'])
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:486, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     484 if hasattr(data, "shape"):
#     485     if len(data.shape) == 1:
# --> 486         if np.isscalar(data[0]):
#     487             plot_data = [data]
#     488         else:
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# company_data

# %%
company_data
# Out:
#             Date        Name    Open    High     Low   Close  Volume
# 8426  2022-01-02  UNILEVERCL  3000.0  3079.0  2985.0  3016.0  1753.0
# 8427  2022-01-03  UNILEVERCL  3080.0  3080.0  2975.0  2977.7  2172.0
# 8428  2022-01-04  UNILEVERCL  3015.0  3015.0  2955.0  2994.3  1454.0
# 8429  2022-01-05  UNILEVERCL  2995.0  3033.0  2995.0  2999.6  3352.0
# 8430  2022-01-06  UNILEVERCL  3002.0  3015.0  2950.0  2963.6  3650.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 48713 2022-06-26  UNILEVERCL  2810.1  2846.0  2810.1  2836.5   119.0
# 48714 2022-06-27  UNILEVERCL  2821.0  2845.0  2821.0  2832.2   217.0
# 48715 2022-06-28  UNILEVERCL  2840.0  2848.0  2840.0  2847.1   460.0
# 48716 2022-06-29  UNILEVERCL  2826.0  2855.0  2826.0  2839.0    68.0
# 48717 2022-06-30  UNILEVERCL  2850.0  2880.0  2828.0  2855.7   239.0
#
# [121 rows x 7 columns]

# %%
specific_companies=['UNILEVERCL']#,'BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]

for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    sns.boxplot(company_data['Close'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 7
#       5 for company in specific_companies:
#       6     company_data=specific_data[specific_data['Name']==company]
# ----> 7     sns.boxplot(company_data['Close'])
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File D:\Anaconda\lib\site-packages\seaborn\categorical.py:486, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     484 if hasattr(data, "shape"):
#     485     if len(data.shape) == 1:
# --> 486         if np.isscalar(data[0]):
#     487             plot_data = [data]
#     488         else:
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
specific_companies=['UNILEVERCL','BEXIMCO','RECKITTBEN','BATBC','SAIHAMCOT']

specific_data=stock_data[stock_data['Name'].isin(specific_companies)]


for company in specific_companies:
    company_data=specific_data[specific_data['Name']==company]
    plt.plot(company_data['Date'],company_data['Volume'],label=company)
    
plt.xlabel('Date')
plt.ylabel('Volume traded')
plt.legend()

plt.grid()

plt.xticks(rotation=45)
plt.show()
